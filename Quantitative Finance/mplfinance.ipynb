# %% [markdown]
# # `mplfinance` — `matplolib`’s relatively unknown library for plotting financial data

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
import yfinance as yf
import mplfinance as mpf

# %% [markdown]
# ## Downloading data

# %%
TICKER = "AAPL"

df = yf.download(TICKER, 
                 start="2020-07-01", 
                 end="2020-12-31", 
                 auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## OHLC chart

# %%
mpf.plot(df["2020-12-01":])

# %%
extra_plot  = mpf.make_addplot(df.loc["2020-12-01":, ["High","Low"]])
mpf.plot(df["2020-12-01":], addplot=extra_plot)

# %% [markdown]
# ## Candlestick chart

# %%
mpf.plot(df["2020-12-01":], type="candle")

# %%
mpf.plot(df["2020-12-01":], type="candle", show_nontrading=True)

# %%
mpf.plot(df, type="candle", mav=(10, 20), volume=True)

# %% [markdown]
# ## Renko chart

# %%
mpf.plot(df, type="renko")

# %%
mpf.plot(df, type="renko", renko_params=dict(brick_size=4))

# %%
mpf.plot(df, type="renko", renko_params=dict(brick_size=2))

# %% [markdown]
# ## Point and Figure

# %%
mpf.plot(df, type="pnf")

# %% [markdown]
# ## Adding style and general prettifying

# %%
mpf.plot(df, figratio=(10, 6), type="candle", 
         mav=(21), volume=True,
         title = f"Price of {TICKER}",
         tight_layout=True, style="binance")

# %%
mpf.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']

# %%
mpf.plot(df, figratio=(10, 6), type="candle", 
         mav=(21), volume=True,
         title = f"Price of {TICKER}",
         tight_layout=True, style="binance", 
         savefig=f"{TICKER}.png")
